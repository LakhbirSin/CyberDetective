# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# Creating list to append tweet data 
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('the Art of War since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned

# %%
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df1
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-12-31 23:58:04+00:00  1609338127956545536
# 1    2022-12-31 23:57:58+00:00  1609338101343858690
# 2    2022-12-31 23:50:55+00:00  1609336328784576513
# 3    2022-12-31 23:49:26+00:00  1609335954514366464
# 4    2022-12-31 23:48:15+00:00  1609335659277291523
# ...                        ...                  ...
# 996  2022-12-27 01:28:32+00:00  1607548955134394370
# 997  2022-12-27 01:10:08+00:00  1607544325696786432
# 998  2022-12-27 01:07:40+00:00  1607543702947495936
# 999  2022-12-27 01:04:36+00:00  1607542934173544450
# 1000 2022-12-27 01:02:15+00:00  1607542339270225921
#
#                                                    Text         Username
# 0     The Ultimate Art of War: A Step-by-Step Illust...  mosciski52ejffd
# 1     they tried to play with my general tso's so i ...        a13george
# 2     @truckdriverpleb Unfortunately that is a fact....   PeterRMacIsaac
# 3     @lexfridman I read most of those and would rec...       levosaurus
# 4     @lexfridman The art of war is going to change ...    BullstreetLLC
# ...                                                 ...              ...
# 996   @David_G1ZQC @TaraBull808 Again... from the Ar...   Vince_Clorotho
# 997   @david_r_morgan If Trump had fired Fauci, then...       VegasRVP24
# 998   @RpsAgainstTrump Art of War advocates spreadin...      MattWaxman7
# 999   "The Essence of Military Operations is Speed" ...    GarryRodgers1
# 1000  The Art of War: Complete Text and Commentaries...    kassulke64ykl
#
# [1001 rows x 4 columns]

# %%
#Remove special character
tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
tweets_df1
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_5580\4276038019.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
#                       Datetime             Tweet Id  \
# 0    2022-12-31 23:58:04+00:00  1609338127956545536
# 1    2022-12-31 23:57:58+00:00  1609338101343858690
# 2    2022-12-31 23:50:55+00:00  1609336328784576513
# 3    2022-12-31 23:49:26+00:00  1609335954514366464
# 4    2022-12-31 23:48:15+00:00  1609335659277291523
# ...                        ...                  ...
# 996  2022-12-27 01:28:32+00:00  1607548955134394370
# 997  2022-12-27 01:10:08+00:00  1607544325696786432
# 998  2022-12-27 01:07:40+00:00  1607543702947495936
# 999  2022-12-27 01:04:36+00:00  1607542934173544450
# 1000 2022-12-27 01:02:15+00:00  1607542339270225921
#
#                                                    Text         Username
# 0     The Ultimate Art of War  A Step by Step Illust...  mosciski52ejffd
# 1     they tried to play with my general tso s so i ...        a13george
# 2      truckdriverpleb Unfortunately that is a fact ...   PeterRMacIsaac
# 3      lexfridman I read most of those and would rec...       levosaurus
# 4      lexfridman The art of war is going to change ...    BullstreetLLC
# ...                                                 ...              ...
# 996    David G1ZQC  TaraBull808 Again    from the Ar...   Vince_Clorotho
# 997    david r morgan If Trump had fired Fauci  then...       VegasRVP24
# 998    RpsAgainstTrump Art of War advocates spreadin...      MattWaxman7
# 999    The Essence of Military Operations is Speed  ...    GarryRodgers1
# 1000  The Art of War  Complete Text and Commentaries...    kassulke64ykl
#
# [1001 rows x 4 columns]

# %%
# Save tweets table
tweets_df1.to_csv('The_art_of_war.csv')

# %%
Cloud = pd.read_csv("The_art_of_war.csv")
Cloud
# Out:
#       Unnamed: 0                   Datetime             Tweet Id  \
# 0              0  2022-12-31 23:58:04+00:00  1609338127956545536
# 1              1  2022-12-31 23:57:58+00:00  1609338101343858690
# 2              2  2022-12-31 23:50:55+00:00  1609336328784576513
# 3              3  2022-12-31 23:49:26+00:00  1609335954514366464
# 4              4  2022-12-31 23:48:15+00:00  1609335659277291523
# ...          ...                        ...                  ...
# 996          996  2022-12-27 01:28:32+00:00  1607548955134394370
# 997          997  2022-12-27 01:10:08+00:00  1607544325696786432
# 998          998  2022-12-27 01:07:40+00:00  1607543702947495936
# 999          999  2022-12-27 01:04:36+00:00  1607542934173544450
# 1000        1000  2022-12-27 01:02:15+00:00  1607542339270225921
#
#                                                    Text         Username
# 0     The Ultimate Art of War  A Step by Step Illust...  mosciski52ejffd
# 1     they tried to play with my general tso s so i ...        a13george
# 2      truckdriverpleb Unfortunately that is a fact ...   PeterRMacIsaac
# 3      lexfridman I read most of those and would rec...       levosaurus
# 4      lexfridman The art of war is going to change ...    BullstreetLLC
# ...                                                 ...              ...
# 996    David G1ZQC  TaraBull808 Again    from the Ar...   Vince_Clorotho
# 997    david r morgan If Trump had fired Fauci  then...       VegasRVP24
# 998    RpsAgainstTrump Art of War advocates spreadin...      MattWaxman7
# 999    The Essence of Military Operations is Speed  ...    GarryRodgers1
# 1000  The Art of War  Complete Text and Commentaries...    kassulke64ykl
#
# [1001 rows x 5 columns]

# %%
# Start with one review:
text = " ".join(i for i in Cloud['Text'])
# Stopword list
stopwords = set(STOPWORDS)
stopwords.update(['https','t','co','will','say','got','first','amp','don','go','s','de','m'])

# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
