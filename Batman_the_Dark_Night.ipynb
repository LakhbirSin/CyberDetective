# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# Creating list to append tweet data 
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Batman : the Dark Night Return since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned

# %%
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df1
# Out:
#                     Datetime             Tweet Id  \
# 0  2022-12-31 01:55:15+00:00  1609005231320317952
# 1  2022-12-29 13:08:42+00:00  1608449933824212992
# 2  2022-12-27 12:51:33+00:00  1607720841156120576
# 3  2022-12-25 01:00:47+00:00  1606817197149626372
# 4  2022-12-18 14:01:59+00:00  1604477075678707713
# ..                       ...                  ...
# 80 2022-06-08 21:00:10+00:00  1534641457264476162
# 81 2022-06-07 18:56:51+00:00  1534248035890372610
# 82 2022-06-02 19:24:29+00:00  1532443053293613056
# 83 2022-06-02 15:45:53+00:00  1532388037904179202
# 84 2022-06-01 17:12:41+00:00  1532047494485508096
#
#                                                  Text         Username
# 0   @Av3rage_Us3r What's your favorite Batman movi...   Jessepinkmam19
# 1   Batman : The dark night returns #3 (août 1986)...       EdHautacam
# 2   @donkeykongdec Hot take. This batman was...OK....      kuma_torres
# 3   @AidanJohnMoffat In the Dark Knight Returns bo...       craigcutch
# 4   @EllipseEnt Aliens, superman 2 , Batman Return...      ShiersJason
# ..                                                ...              ...
# 80  After being saved by Batman on the night he re...         GameStop
# 81  Ok, lo admito: Me encantaría un live action de...   VampireMaquiav
# 82  @Barrymore234 @DcRational @BlackMajikMan90 Wat...  JosueLovesMovie
# 83  @LordCastroP 5 amigos y seis datos Versión Fri...      Jocampos998
# 84  @mspeacherino This latest movie version of The...       FutureInVC
#
# [85 rows x 4 columns]

# %%
#Remove special character
tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
tweets_df1
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_1800\4276038019.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
#                     Datetime             Tweet Id  \
# 0  2022-12-31 01:55:15+00:00  1609005231320317952
# 1  2022-12-29 13:08:42+00:00  1608449933824212992
# 2  2022-12-27 12:51:33+00:00  1607720841156120576
# 3  2022-12-25 01:00:47+00:00  1606817197149626372
# 4  2022-12-18 14:01:59+00:00  1604477075678707713
# ..                       ...                  ...
# 80 2022-06-08 21:00:10+00:00  1534641457264476162
# 81 2022-06-07 18:56:51+00:00  1534248035890372610
# 82 2022-06-02 19:24:29+00:00  1532443053293613056
# 83 2022-06-02 15:45:53+00:00  1532388037904179202
# 84 2022-06-01 17:12:41+00:00  1532047494485508096
#
#                                                  Text         Username
# 0    Av3rage Us3r What s your favorite Batman movi...   Jessepinkmam19
# 1   Batman   The dark night returns  3  ao t 1986 ...       EdHautacam
# 2    donkeykongdec Hot take  This batman was   OK ...      kuma_torres
# 3    AidanJohnMoffat In the Dark Knight Returns bo...       craigcutch
# 4    EllipseEnt Aliens  superman 2   Batman Return...      ShiersJason
# ..                                                ...              ...
# 80  After being saved by Batman on the night he re...         GameStop
# 81  Ok  lo admito  Me encantar a un live action de...   VampireMaquiav
# 82   Barrymore234  DcRational  BlackMajikMan90 Wat...  JosueLovesMovie
# 83   LordCastroP 5 amigos y seis datos Versi n Fri...      Jocampos998
# 84   mspeacherino This latest movie version of The...       FutureInVC
#
# [85 rows x 4 columns]

# %%
# Save tweets table
tweets_df1.to_csv('Batman_:_the_Dark_Night.csv')

# %%
Cloud = pd.read_csv("Batman_:_the_Dark_Night.csv")
Cloud
# Out:
#     Unnamed: 0                   Datetime             Tweet Id  \
# 0            0  2022-12-31 01:55:15+00:00  1609005231320317952
# 1            1  2022-12-29 13:08:42+00:00  1608449933824212992
# 2            2  2022-12-27 12:51:33+00:00  1607720841156120576
# 3            3  2022-12-25 01:00:47+00:00  1606817197149626372
# 4            4  2022-12-18 14:01:59+00:00  1604477075678707713
# ..         ...                        ...                  ...
# 80          80  2022-06-08 21:00:10+00:00  1534641457264476162
# 81          81  2022-06-07 18:56:51+00:00  1534248035890372610
# 82          82  2022-06-02 19:24:29+00:00  1532443053293613056
# 83          83  2022-06-02 15:45:53+00:00  1532388037904179202
# 84          84  2022-06-01 17:12:41+00:00  1532047494485508096
#
#                                                  Text         Username
# 0    Av3rage Us3r What s your favorite Batman movi...   Jessepinkmam19
# 1   Batman   The dark night returns  3  ao t 1986 ...       EdHautacam
# 2    donkeykongdec Hot take  This batman was   OK ...      kuma_torres
# 3    AidanJohnMoffat In the Dark Knight Returns bo...       craigcutch
# 4    EllipseEnt Aliens  superman 2   Batman Return...      ShiersJason
# ..                                                ...              ...
# 80  After being saved by Batman on the night he re...         GameStop
# 81  Ok  lo admito  Me encantar a un live action de...   VampireMaquiav
# 82   Barrymore234  DcRational  BlackMajikMan90 Wat...  JosueLovesMovie
# 83   LordCastroP 5 amigos y seis datos Versi n Fri...      Jocampos998
# 84   mspeacherino This latest movie version of The...       FutureInVC
#
# [85 rows x 5 columns]

# %%
# Start with one review:
text = " ".join(i for i in Cloud['Text'])
# Stopword list
stopwords = set(STOPWORDS)
stopwords.update(['https','t','co','will','say','got','first','amp','don','go','s','de','m','je','La','re','d','c'])

# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
