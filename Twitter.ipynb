# %% [markdown]
# # Etape 2 : Collecte des tweets

# %%
#pip install snscrape

# %%
# importing libraries and packages
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data 
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('the Art of War since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned
    
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('The song of Achille since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned
    
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(' Batman : the Dark Night Return since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned
    

for i,tweet in enumerate(sntwitter.TwitterSearchScraper(' The Picture of Dorian Gray since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned
    
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(' The Book Thief since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned
    
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df1
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-12-31 23:58:04+00:00  1609338127956545536
# 1    2022-12-31 23:50:55+00:00  1609336328784576513
# 2    2022-12-31 23:49:26+00:00  1609335954514366464
# 3    2022-12-31 23:48:15+00:00  1609335659277291523
# 4    2022-12-31 23:47:13+00:00  1609335398509195268
# ...                        ...                  ...
# 3136 2022-12-14 03:35:23+00:00  1602869837004349443
# 3137 2022-12-14 03:11:12+00:00  1602863750653935617
# 3138 2022-12-14 03:06:28+00:00  1602862560570920960
# 3139 2022-12-14 02:00:54+00:00  1602846057746104324
# 3140 2022-12-14 01:51:16+00:00  1602843633798942720
#
#                                                    Text         Username
# 0     The Ultimate Art of War: A Step-by-Step Illust...  mosciski52ejffd
# 1     @truckdriverpleb Unfortunately that is a fact....   PeterRMacIsaac
# 2     @lexfridman I read most of those and would rec...       levosaurus
# ...

# %%
#Remove special character
tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
tweets_df1
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_14112\3672077394.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
#                       Datetime             Tweet Id  \
# 0    2022-12-31 23:58:04+00:00  1609338127956545536
# 1    2022-12-31 23:50:55+00:00  1609336328784576513
# 2    2022-12-31 23:49:26+00:00  1609335954514366464
# 3    2022-12-31 23:48:15+00:00  1609335659277291523
# 4    2022-12-31 23:47:13+00:00  1609335398509195268
# ...                        ...                  ...
# 3136 2022-12-14 03:35:23+00:00  1602869837004349443
# 3137 2022-12-14 03:11:12+00:00  1602863750653935617
# 3138 2022-12-14 03:06:28+00:00  1602862560570920960
# 3139 2022-12-14 02:00:54+00:00  1602846057746104324
# 3140 2022-12-14 01:51:16+00:00  1602843633798942720
#
#                                                    Text         Username
# ...

# %%
# Save tweets table
tweets_df1.to_csv('Tweets.csv')
