# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# Creating list to append tweet data 
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('The Book Thief since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned

# %%
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df1
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-12-31 23:14:49+00:00  1609327243360190467
# 1    2022-12-31 22:32:53+00:00  1609316692232122370
# 2    2022-12-31 22:19:43+00:00  1609313379583397889
# 3    2022-12-31 22:14:50+00:00  1609312147099758594
# 4    2022-12-31 21:51:49+00:00  1609306355684503552
# ...                        ...                  ...
# 996  2022-12-14 06:17:33+00:00  1602910646408204295
# 997  2022-12-14 03:35:23+00:00  1602869837004349443
# 998  2022-12-14 03:11:12+00:00  1602863750653935617
# 999  2022-12-14 03:06:28+00:00  1602862560570920960
# 1000 2022-12-14 02:00:54+00:00  1602846057746104324
#
#                                                    Text         Username
# 0     @FiruzAllayev - Do Androids Dream of Electric ...  Sardor__Islomov
# 1     After a long 2022 I am SO PROUD to say that I ...  SheeIcho_kawaii
# 2     19. Six of Crows - L. Bardugo ⭐ 4,75\n20. Croo...   ColodreroRamon
# 3     @MatRyanELATeach @toxicorange66 @mental_willne...    SparkyTeacher
# 4     At this weekend, I plan to watch Anime Fantasy...  bingbingliucdc1
# ...                                                 ...              ...
# 996   @palkisu @crmiller1 The book thief by Marcus Z...      vidhishiste
# 997   Do you struggle picking out what to read next?...       nemo_nista
# 998   At this weekend, I plan to watch Crime Action ...  bingbingliucdc1
# 999   @she_is_ghariba Quran\nThe book thief\nTuesday...  __dontaskwhy__x
# 1000  @r4hema six of crows, the bell jar, the book t...       c13ment1ne
#
# [1001 rows x 4 columns]

# %%
#Remove special character
tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
tweets_df1
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_10484\4276038019.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
#                       Datetime             Tweet Id  \
# 0    2022-12-31 23:14:49+00:00  1609327243360190467
# 1    2022-12-31 22:32:53+00:00  1609316692232122370
# 2    2022-12-31 22:19:43+00:00  1609313379583397889
# 3    2022-12-31 22:14:50+00:00  1609312147099758594
# 4    2022-12-31 21:51:49+00:00  1609306355684503552
# ...                        ...                  ...
# 996  2022-12-14 06:17:33+00:00  1602910646408204295
# 997  2022-12-14 03:35:23+00:00  1602869837004349443
# 998  2022-12-14 03:11:12+00:00  1602863750653935617
# 999  2022-12-14 03:06:28+00:00  1602862560570920960
# 1000 2022-12-14 02:00:54+00:00  1602846057746104324
#
#                                                    Text         Username
# 0      FiruzAllayev   Do Androids Dream of Electric ...  Sardor__Islomov
# 1     After a long 2022 I am SO PROUD to say that I ...  SheeIcho_kawaii
# 2     19  Six of Crows   L  Bardugo   4 75 20  Crook...   ColodreroRamon
# 3      MatRyanELATeach  toxicorange66  mental willne...    SparkyTeacher
# 4     At this weekend  I plan to watch Anime Fantasy...  bingbingliucdc1
# ...                                                 ...              ...
# 996    palkisu  crmiller1 The book thief by Marcus Z...      vidhishiste
# 997   Do you struggle picking out what to read next ...       nemo_nista
# 998   At this weekend  I plan to watch Crime Action ...  bingbingliucdc1
# 999    she is ghariba Quran The book thief Tuesdays ...  __dontaskwhy__x
# 1000   r4hema six of crows  the bell jar  the book t...       c13ment1ne
#
# [1001 rows x 4 columns]

# %%
# Save tweets table
tweets_df1.to_csv('The_Book_Thief.csv')

# %%
Cloud = pd.read_csv("The_Book_Thief.csv")
Cloud
# Out:
#       Unnamed: 0                   Datetime             Tweet Id  \
# 0              0  2022-12-31 23:14:49+00:00  1609327243360190467
# 1              1  2022-12-31 22:32:53+00:00  1609316692232122370
# 2              2  2022-12-31 22:19:43+00:00  1609313379583397889
# 3              3  2022-12-31 22:14:50+00:00  1609312147099758594
# 4              4  2022-12-31 21:51:49+00:00  1609306355684503552
# ...          ...                        ...                  ...
# 996          996  2022-12-14 06:17:33+00:00  1602910646408204295
# 997          997  2022-12-14 03:35:23+00:00  1602869837004349443
# 998          998  2022-12-14 03:11:12+00:00  1602863750653935617
# 999          999  2022-12-14 03:06:28+00:00  1602862560570920960
# 1000        1000  2022-12-14 02:00:54+00:00  1602846057746104324
#
#                                                    Text         Username
# 0      FiruzAllayev   Do Androids Dream of Electric ...  Sardor__Islomov
# 1     After a long 2022 I am SO PROUD to say that I ...  SheeIcho_kawaii
# 2     19  Six of Crows   L  Bardugo   4 75 20  Crook...   ColodreroRamon
# 3      MatRyanELATeach  toxicorange66  mental willne...    SparkyTeacher
# 4     At this weekend  I plan to watch Anime Fantasy...  bingbingliucdc1
# ...                                                 ...              ...
# 996    palkisu  crmiller1 The book thief by Marcus Z...      vidhishiste
# 997   Do you struggle picking out what to read next ...       nemo_nista
# 998   At this weekend  I plan to watch Crime Action ...  bingbingliucdc1
# 999    she is ghariba Quran The book thief Tuesdays ...  __dontaskwhy__x
# 1000   r4hema six of crows  the bell jar  the book t...       c13ment1ne
#
# [1001 rows x 5 columns]

# %%
# Start with one review:
text = " ".join(i for i in Cloud['Text'])
# Stopword list
stopwords = set(STOPWORDS)
stopwords.update(['https','t','co','will','say','got','first','amp','don','go','s','de','m','je','La','re','d','c'])

# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
