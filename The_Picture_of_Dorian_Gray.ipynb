# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# Creating list to append tweet data 
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('The Picture of Dorian Gray since:2022-06-01 until:2023-01-01 ').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned

# %%
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df1
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-12-31 22:37:16+00:00  1609317795606446080
# 1    2022-12-31 22:37:15+00:00  1609317789029863424
# 2    2022-12-31 22:33:01+00:00  1609316723215196160
# 3    2022-12-31 22:32:12+00:00  1609316518386630656
# 4    2022-12-31 22:22:52+00:00  1609314170541072385
# ...                        ...                  ...
# 996  2022-12-18 23:28:26+00:00  1604619629090979840
# 997  2022-12-18 22:59:36+00:00  1604612370910908416
# 998  2022-12-18 22:55:38+00:00  1604611373559943171
# 999  2022-12-18 22:43:06+00:00  1604608218377986048
# 1000 2022-12-18 22:40:24+00:00  1604607541568327680
#
#                                                    Text         Username
# 0     The Picture of Dorian Gray N3UBOVQ\n\nhttps://...      Marianna55H
# 1     The Uncensored Picture of Dorian Gray: by Osca...      bergnaumwsg
# 2     @lexfridman Karamazov in a week is a bit ambit...   Kasper43674645
# ...

# %%
#Remove special character
tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
tweets_df1
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_11956\4276038019.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   tweets_df1['Text'] =  tweets_df1['Text'].str.replace(r"[^a-zA-Z0-9]"," ")
#                       Datetime             Tweet Id  \
# 0    2022-12-31 22:37:16+00:00  1609317795606446080
# 1    2022-12-31 22:37:15+00:00  1609317789029863424
# 2    2022-12-31 22:33:01+00:00  1609316723215196160
# 3    2022-12-31 22:32:12+00:00  1609316518386630656
# 4    2022-12-31 22:22:52+00:00  1609314170541072385
# ...                        ...                  ...
# 996  2022-12-18 23:28:26+00:00  1604619629090979840
# 997  2022-12-18 22:59:36+00:00  1604612370910908416
# 998  2022-12-18 22:55:38+00:00  1604611373559943171
# 999  2022-12-18 22:43:06+00:00  1604608218377986048
# 1000 2022-12-18 22:40:24+00:00  1604607541568327680
#
#                                                    Text         Username
# ...

# %%
# Save tweets table
tweets_df1.to_csv('The_Picture_of_Dorian_Gray.csv')

# %%
Cloud = pd.read_csv("The_Picture_of_Dorian_Gray.csv")
Cloud
# Out:
#       Unnamed: 0                   Datetime             Tweet Id  \
# 0              0  2022-12-31 22:37:16+00:00  1609317795606446080
# 1              1  2022-12-31 22:37:15+00:00  1609317789029863424
# 2              2  2022-12-31 22:33:01+00:00  1609316723215196160
# 3              3  2022-12-31 22:32:12+00:00  1609316518386630656
# 4              4  2022-12-31 22:22:52+00:00  1609314170541072385
# ...          ...                        ...                  ...
# 996          996  2022-12-18 23:28:26+00:00  1604619629090979840
# 997          997  2022-12-18 22:59:36+00:00  1604612370910908416
# 998          998  2022-12-18 22:55:38+00:00  1604611373559943171
# 999          999  2022-12-18 22:43:06+00:00  1604608218377986048
# 1000        1000  2022-12-18 22:40:24+00:00  1604607541568327680
#
#                                                    Text         Username
# 0     The Picture of Dorian Gray N3UBOVQ  https   t ...      Marianna55H
# ...

# %%
# Start with one review:
text = " ".join(i for i in Cloud['Text'])
# Stopword list
stopwords = set(STOPWORDS)
stopwords.update(['https','t','co','will','say','got','first','amp','don','go','s','de','m','je','La','re','d','c'])

# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
